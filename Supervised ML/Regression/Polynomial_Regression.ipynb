# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

plt.scatter(x, y)
plt.show()

# %%
import numpy
import matplotlib.pyplot as plt

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 3))

myline = numpy.linspace(1, 22, 100)

plt.scatter(x, y)
plt.plot(myline, mymodel(myline))
plt.show()

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error,r2_score

x = [1,2,3,5,6,7,8,9,10,12,13,14,15,16,18,19,21,22]
y = [100,90,80,60,60,55,60,65,70,70,75,76,78,79,90,99,99,100]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 2))
print(mymodel.c)

mae = mean_absolute_error(y, mymodel(x))
mse = mean_squared_error(y, mymodel(x))
rmse = np.sqrt(mse)
r2=r2_score(y, mymodel(x))

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R2: {r2}")
print(100*'_')
# Out:
# [ 0.300185   -5.85858457 94.01812448]
# MAE: 6.263952455249868
# MSE: 52.7659847642819
# RMSE: 7.264019876368862
# R2: 0.759777160189589
# ____________________________________________________________________________________________________

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error,r2_score

x = [3,4,5,6,7]
y = [2.5,3.2,3.8,6.5,11.5]

mymodel = numpy.poly1d(numpy.polyfit(x, y, 2))
print(mymodel.c)

mae = mean_absolute_error(y, mymodel(x))
mse = mean_squared_error(y, mymodel(x))
rmse = np.sqrt(mse)
r2=r2_score(y, mymodel(x))

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R2: {r2}")
print(100*'_')
# Out:
# [ 0.76428571 -5.51285714 12.42857143]
# MAE: 0.32228571428571584
# MSE: 0.12662857142857167
# RMSE: 0.35584908518720637
# R2: 0.9883140853240521
# ____________________________________________________________________________________________________

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error,r2_score

X = [3,4,5,6,7]
y = [2.5,3.2,3.8,6.5,11.5]

#mymodel = numpy.poly1d(numpy.polyfit(x, y, 2))
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(np.array(X).reshape(-1, 1))

clf = LinearRegression()
clf.fit(X_poly, y)
predicted_X = clf.predict(X_poly)
print("intercept ",{clf.intercept_})
print(clf.coef_)

mae = mean_absolute_error(y, predicted_X)
mse = mean_squared_error(y, predicted_X)
rmse = np.sqrt(mse)
r2=r2_score(y, predicted_X)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R2: {r2}")
print(100*'_')
# Out:
# intercept  {12.428571428571345}
# [ 0.         -5.51285714  0.76428571]
# MAE: 0.32228571428571334
# MSE: 0.12662857142857126
# RMSE: 0.3558490851872058
# R2: 0.9883140853240521
# ____________________________________________________________________________________________________

# %%
plt.figure(figsize=(10, 6))
plt.title("polynomial regression )", size=16)
plt.scatter(X, y)
plt.plot(X, predicted_X, c="red")
plt.show()

# %%
df = pd.read_csv("https://raw.githubusercontent.com/mujahidashraf/data/ab06025689b4d8904b6a3e330dc8012cf4316f92/data.csv")
le = LabelEncoder()
df['Car'] = le.fit_transform(df['Car'])
df['Model'] = le.fit_transform(df['Model'])
df.head()
# Out:
#    Car  Model  Volume  Weight  CO2
# 0   14     10    1000     790   99
# 1   10     29    1200    1160   95
# 2   12     14    1000     929   95
# 3    2      4     900     865   90
# 4    9     16    1500    1140  105

# %%
X = df[['Car'	,'Model',	'Volume',	'Weight']]
X.head()
# Out:
#    Car  Model  Volume  Weight
# 0   14     10    1000     790
# 1   10     29    1200    1160
# 2   12     14    1000     929
# 3    2      4     900     865
# 4    9     16    1500    1140

# %%
y = df['CO2']
y.head()
# Out:
# 0     99
# 1     95
# 2     95
# 3     90
# 4    105
# Name: CO2, dtype: int64

# %%
poly = PolynomialFeatures(degree=4)
co2_poly = poly.fit_transform(X)

clf = LinearRegression()
clf.fit(co2_poly, y)
predicted_co2 = clf.predict(co2_poly)

#mymodel = numpy.poly1d(numpy.polyfit(X, y, 3))
mae = mean_absolute_error(y, predicted_co2)
mse = mean_squared_error(y, predicted_co2)
rmse = np.sqrt(mse)
r2=r2_score(y, predicted_co2)

print(f"MAE: {mae}")
print(f"MSE: {mse}")
print(f"RMSE: {rmse}")
print(f"R2: {r2}")
print(100*'_')
# Out:
# MAE: 1.4203970345584418e-09
# MSE: 4.486084722277161e-18
# RMSE: 2.118037941651934e-09
# R2: 1.0
# ____________________________________________________________________________________________________

# %%
len(co2_poly)
# Out:
# 36
